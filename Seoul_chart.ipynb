# %%
#참고 문헌
#https://github.com/corazzon/OpenDataWrangling/blob/master/commercial_store.ipynb
#Neowizard

import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", category=UserWarning)

# %%
#엑셀 도구
import pandas as pd
#시각화 도구
from plotnine import *
#|

# %%
#파일 경로 지정
# %ls C:\Users\David\Desktop\commercial_store
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: E259-D6CB
#
#  C:\Users\David\Desktop\commercial_store 디렉터리
#
# 2020-02-21  오후 04:37            12,800 (필독) 파일 열람 방법.hwp
# 2020-07-29  오후 05:07    <DIR>          .
# 2020-07-29  오후 05:07    <DIR>          ..
# 2020-01-08  오후 04:18       264,920,940 201912_01.csv
# 2020-01-08  오후 04:29       240,255,224 201912_02.csv
# 2020-02-21  오후 04:30       400,653,293 201912_03.csv
# 2020-02-21  오후 04:31       357,482,028 201912_04.csv
# 2020-07-29  오후 04:14       240,468,403 test.csv
# 2020-07-29  오후 04:32       264,965,477 test2.csv
# 2020-07-29  오후 05:07       199,397,546 test3.csv
#                8개 파일       1,968,155,711 바이트
#                2개 디렉터리  26,399,145,984 바이트 남음

# %%
#파일 연결
shop = pd.read_csv("C:/Users/David/Desktop/commercial_store/test3.csv", 
                   encoding='cp949', 
                   engine='python')

# %%
#총 행렬 갯수
shop.shape
# Out:
# (573680, 39)

# %%
#상위 3건 노출
shop.head(3)
# Out:
#      상가업소번호            상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  19905471         와라와라호프         NaN         Q       음식       Q09     유흥주점
# 1  19911397  커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12   커피점/카페
# 2  19911801           프로포즈         NaN         Q       음식       Q09     유흥주점
#
#   상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...        건물관리번호   건물명  \
# 0    Q09A01        호프/맥주   I56219  ...  1.168010e+24  대치상가
# 1    Q12A01  커피전문점/카페/다방   I56220  ...  1.168010e+24   NaN
# 2    Q09A01        호프/맥주   I56219  ...  1.154510e+24   NaN
#
#                   도로명주소   구우편번호   신우편번호  동정보 층정보  호정보          경도         위도
# 0  서울특별시 강남구 남부순환로 2933  135280  6280.0  NaN   1  NaN  127.061026  37.493922
# 1    서울특별시 강남구 선릉로93길 6  135080  6149.0  NaN   1  NaN  127.047883  37.505675
# 2    서울특별시 금천구 가산로 34-6  153010  8545.0  NaN   1  NaN  126.899220  37.471711
#
# [3 rows x 39 columns]

# %%
shop.tail()
# Out:
#           상가업소번호       상호명  지점명 상권업종대분류코드  상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 573675  16394290   비파티세리공덕  NaN         Q        음식       Q01            한식
# 573676  16336474     앤탑PC방  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 573677  16336218  오즈아레나PC방  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 573678  16335152    파인트리네일  NaN         F     생활서비스       F01       이/미용/건강
# 573679  16335150    마이리틀네일  NaN         F     생활서비스       F01       이/미용/건강
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...        건물관리번호       건물명  \
# 573675    Q01A01  한식/백반/한정식   I56111  ...  1.144010e+24       NaN
# 573676    N01A01     인터넷PC방   R91222  ...  1.120010e+24  으뜸프린팅(주)
# 573677    N01A01     인터넷PC방   R91222  ...  1.168010e+24      한맥빌딩
# 573678    F01A02     발/네일케어   S96119  ...  1.156010e+24  서울국제금융센터
# 573679    F01A02     발/네일케어   S96119  ...  1.132010e+24   현대타운아파트
#
#                          도로명주소   구우편번호   신우편번호  동정보  층정보  호정보          경도  \
# ...

# %%
shop.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
shop[["상권업종중분류명"]]
# Out:
#             상권업종중분류명
# 0               유흥주점
# 1             커피점/카페
# 2               유흥주점
# 3              패스트푸드
# 4           대중목욕탕/휴게
# ...              ...
# 573675            한식
# 573676  PC/오락/당구/볼링등
# 573677  PC/오락/당구/볼링등
# 573678       이/미용/건강
# 573679       이/미용/건강
#
# [573680 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 실습환경에 맞는 한글폰트 설정을 해주세요.
# Window 의 한글 폰트 설정
plt.rc('font',family='Malgun Gothic')
# Mac 의 한글 폰트 설정
#plt.rc('font', family='AppleGothic')

# %%
# Pandas 의 plot 으로 위도와 경도를 산점도로 그려봅니다.
shop[:1000].plot.scatter(x='경도', y='위도', grid=True)

# %%
# 데이터를 보니 서울과 부산만 있는거 같다. 
# 그래서 서울과 그 외 데이터로 나눠봤다.
shop_seoul = shop.loc[shop['도로명주소'].str.startswith('서울')]
shop_except_seoul = shop.loc[~shop['도로명주소'].str.startswith('서울')]
print(shop_seoul.shape)
print(shop_except_seoul.shape)
# Out:
# (407376, 39)
# (166304, 39)

# %%
# Pandas 의 plot 으로 위도와 경도를 산점도로 그려봅니다.
# 그래프가 너무 찌그러져 보이지 않도록 그래프 사이즈를 figsize=(16, 12) 로 조정합니다.
shop_seoul.plot.scatter(x='경도', y='위도', figsize=(16, 12), grid=True)

# %%
print(shop.shape)
shop['시도'] = shop['도로명주소'].str.split(' ', expand=True)[0]
shop['구군'] = shop['도로명주소'].str.split(' ', expand=True)[1]
print(shop.shape)
shop.columns
# Out:
# (573680, 39)
# (573680, 41)
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도', '시도', '구군'],
#       dtype='object')

# %%
shop_seoul['상권업종대분류명'].value_counts()
# Out:
# 음식          132889
# 소매          126209
# 생활서비스        67137
# 학문/교육        31509
# 의료           19011
# 부동산          15701
# 관광/여가/오락     11643
# 숙박            3083
# 스포츠            194
# Name: 상권업종대분류명, dtype: int64

# %%
# 전체 데이터를 출력하는데 시간이 너무 오래 걸린다면 
# data=shop_seoul 대신 data=shop_seoul[:10000] 로 만개의 데이터만 가져와서 출력해 보셔도 됩니다.
#서울시 상권 분석
plt.figure(figsize=(16, 12))
sns.scatterplot(data=shop_seoul[:10000], x='경도', y='위도', hue='상권업종대분류명')

# %%
#서울 음식점 분포 Scatterplot
shop_seoul_realty = shop_seoul[shop_seoul['상권업종대분류명'] == '음식']

# (ggplot(shop_seoul_realty)
#  + aes(x='경도', y='위도', color='상권업종중분류명')
#  + geom_point(size=0.2)
#  + theme(text=element_text(family='NanumBarunGothic'))
#  + scale_fill_gradient(low = 'blue', high = 'green') 
# )

# %%
plt.figure(figsize=(16, 12))
sns.scatterplot(data=shop_seoul_realty, x='경도', y='위도', hue='상권업종중분류명')

# %%
shop_seoul['상권업종대분류명'].value_counts()
# Out:
# 음식          132889
# 소매          126209
# 생활서비스        67137
# 학문/교육        31509
# 의료           19011
# 부동산          15701
# 관광/여가/오락     11643
# 숙박            3083
# 스포츠            194
# Name: 상권업종대분류명, dtype: int64

# %%
#음식점 총 개수 132889 rows × 39 columns
shop1 = shop_seoul[shop_seoul['상권업종대분류명'] == '음식']

shop1
# Out:
#           상가업소번호            상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       19905471         와라와라호프         NaN         Q       음식       Q09
# 1       19911397  커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12
# 2       19911801           프로포즈         NaN         Q       음식       Q09
# 5       19983535            초밥왕         NaN         Q       음식       Q03
# 6       19964615          석봉토스트         NaN         Q       음식       Q07
# ...          ...            ...         ...       ...      ...       ...
# 573658  16373442         브레드앤로즈         NaN         Q       음식       Q08
# 573669  16311392         스테프핫도그         NaN         Q       음식       Q07
# 573670  16311360           평창갈비         NaN         Q       음식       Q01
# 573671  16372354            휴돈정         NaN         Q       음식       Q06
# 573675  16394290        비파티세리공덕         NaN         Q       음식       Q01
#
#        상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...        건물관리번호       건물명  \
# ...

# %%
#유흥주점 검색 17387 rows × 39 columns
shop2  = shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '유흥주점')]

#패스트푸드 5718 rows × 39 columns
shop3 = shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '패스트푸드')]

#커피점/카페 18920 rows × 39 columns
shop4=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '커피점/카페')]

# 일식/수산물  9400 rows × 39 columns
shop5=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '일식/수산물')]

#분식 12870 rows × 39 columns
shop6=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '분식')]

#한식41537 rows × 39 columns
shop7=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '한식')]

#중식 3159 rows × 39 columns
shop8=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '중식')]

#별식/퓨전요리 3293 rows × 39 columns
shop9=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '별식/퓨전요리')]

#기타음식업 349 rows × 39 columns
shop10=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '기타음식업')]

#음식배달서비스 101 rows × 39 columns
shop11=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '음식배달서비스')]

#제과제빵떡케익 5443 rows × 39 columns
shop12=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '제과제빵떡케익')]

#닭/오리요리 7012 rows × 39 columns
shop13=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '닭/오리요리')]

#부페 500 rows × 39 columns
shop14=shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '부페')]

#양식 7200 rows × 39 columns
shop15 = shop_seoul[(shop_seoul['상권업종대분류명'] == '음식')&(shop_seoul['상권업종중분류명'] == '양식')]

# %%
shop15
# Out:
#           상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 37      20022551  해마로숯불바베큐  NaN         Q       음식       Q06       양식
# 562     22485152        카렘  NaN         Q       음식       Q06       양식
# 621     22743780      끼리끼리  NaN         Q       음식       Q06       양식
# 710     23172677   브루본스테이크  NaN         Q       음식       Q06       양식
# 714     23158417   가이야레스토랑  NaN         Q       음식       Q06       양식
# ...          ...       ...  ...       ...      ...       ...      ...
# 572730  16374507     제이에스엠  NaN         Q       음식       Q06       양식
# 572818  16389078      노말살롱  NaN         Q       음식       Q06       양식
# 573256  16388419      칠하나둘  NaN         Q       음식       Q06       양식
# 573257  16388370       스테이  NaN         Q       음식       Q06       양식
# 573671  16372354       휴돈정  NaN         Q       음식       Q06       양식
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...        건물관리번호     건물명  \
# ...

# %%
import numpy as np
#막대그래프 그리기
y1_value = (17387,5718,18920,9400,12870,41537,3159,3293,349,101,5443,7012,500,7200)
x_name = ('유흥주점','페스트푸드','카페','일식/수산물','분식','한식','중식','별식/퓨전','기타','음식배달','제과제빵/떡','닭/오리','부페','양식')
n_groups = len(x_name)
index = np.arange(n_groups)

plt.bar(index, y1_value, tick_label=x_name, align='center')
plt.rcParams['axes.grid'] = True
#Plot 크기
plt.rcParams["figure.figsize"] = (25,15)


plt.xlabel('점포 이름')
plt.ylabel('점포 수)')
plt.title('서울시 업종별 점포 수')
plt.xlim( -1, n_groups)
plt.ylim( 0, 50000)
plt.show()
